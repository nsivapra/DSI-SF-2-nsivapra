# %% [markdown]
# # Introduction

# %% [markdown]
# The definition of a refugee, according to the 1967 Protocol Relating to the Status of Refugees, is an individual who due to fear of being persecuted for reasons of race, religion, nationality, membership of a political group, is outside his/her national country, and is unable to find protection in his/her national country. People who move in groups to avoid war or civil conflict are often considered as refugees. A refugee isn't an individual who stateless or denied entrance into a country. Instead the term "internally displaced people" (IDP) is used to define those individuals who may have moved for the same reasons as refugees but have not crossed the border. Recently Europe had a migration crisis, in which more than a million refugees crossed into Europe, causing a division in the European Union regarding the best way to deal with resettling people. This problem has caused the EU to relocate most of their refugees in Italy and Greece. Between the years 2010 and 2015 there has been a major spike in the number of refugees trying to find asylum. Due to this spike this has led to the European refugee crisis, in which there have been accidents with transportation and overpopulation. According to the UNHCR, the top three nationalities of the refugees, between January 2015 and March 2016 were Syria, Afghan, and Iraq. In 2015 the demographic of refugees and migrants, were 58% men, 17% women, and 25% children. The number of deaths hit an all time high in April 2015, when five boats carrying 2000 migrants to Europe sank in the Mediterranean Sea, in which the death toll was estimated at 1,200 people.
#
# The Syrian Conflict has been an ongoing issue in which 250,000 citizens have lost their lives over a war that started with an armed conflict. Similarly there have been multiple civil wars and protests that have led citizens to find asylum in different countries. After reading into these conflicts, I decided to look into the recent trends in the acceptance of refugees. Previously there have been issues with refugees being treated poorly, and lack of a safe community. By looking into a country's profile, including the population, murder rate by 1000, poverty, etc I hope to be able to see the correlation between these variables and the refugees in 2015. Similarly I hope to see if the country's profile can predict if the country previously had a civil war or a famine strike in the past 15 years.

# %% [markdown]
# # Visualizations

# %%
from IPython.display import Image
Image(filename='../Images/HeatMap.png')

# %% [markdown]
# This heat map shows the correlation (relationship) between each numeric variable against each other, in a visually appealing manner. The legend at the right maps the color of the square with the range of correlation, as the square gets darker the relationship is stronger. A blue colored square represents a negative relationship between the variables while red represents a positive relationship. An example of a strong positive relationship is between Poverty and Children out of school, which realistically makes sense. As poverty increases the amount of immigrants decrease which is a realistic observation.

# %%
Image(filename='../Images/Rain-Ref.png')

# %% [markdown]
# The jointplot visualization shows the relationship between the amount of Rainfall in ml and the Number of Refugees in 2015. A jointplot includes a histogram showing the distribution of the Rainfall and Refugees in 2015, and a line representing the correlation. As the rainfall increases the number of refugees finding asylum in the country decreases. Looking into the Pearson r score,which represents the slope, we can say the variables have a moderate negative correlation. The histograms for rain shows the most common value is 1000 ml, while the most common number of refugees is below 500,000.

# %%
Image(filename='../Images/Imm-Ref.png')

# %% [markdown]
# This visualization is an example of a positive relationship between the number of Immigrant population and Refugees in 2015. As the number of immigrant population increases the number of Refugees in 2015 increases. Based on the Pearson r value, which is the slope, we can say there is a moderate positive correlation between both variables. Looking into the histograms the most common number of Immigrants is between 0 and 10000000, while the number of refugees falls between 0 and 500000.

# %%
Image(filename='../Images/Continent.png')

# %% [markdown]
# The graph above displays the number of refugees in 2010 and 2015 grouped by the 6 continents, excluding Antarctica. We can clearly see Asia accepts the most refugees in both years while North America accepts the least. Breaking it down by year, in 2010 Oceania accepted the least number of refugees; however, in 2015 North America accepted the least. A bar graph showing two variables is extremely helpful in seeing the difference between each year compared to the other continents.

# %%
Image(filename='../Images/Government.png')

# %% [markdown]
# The bar graph shows the number of refugees in 2010 and 2015 by government. Looking at the bar graph we can see that Consitutional Monarchy had the highest increase in terms of refugees, while Republic had the least increase. This graph would be helpful in showing the difference between the government's take on accepting refugees and a possible indication on the way they treat them.

# %%
Image(filename='../Images/Gender.png')

# %% [markdown]
# The box plot is helpful in showing the overall female and male population in the world. According to the plot the average percentage of female population is 50.3% while male population is 49.7%.

# %%
Image(filename='../Images/Line.png')

# %% [markdown]
# The line graph above shows the trends of murder rate and children out of school by continent. Looking at the graph we can see that Europe is the optimal continent as it has the least number of murder, and children out of school. Africa is probably the least optimal continent as it has the highest children out of school, and the third highest murder rate.

# %%
Image(filename='../Images/Country.png')

# %% [markdown]
# The bar chart is used to show the countries who have taken more than 100000 refugees in both 2010 and 2015. The red bar represents the number of refugees accepted in 2010, while the purple bar represents the number of refugees accepted in 2015.

# %% [markdown]
# # Models

# %% [markdown]
# The linear regression model is helpful in predicting the target variable (Number of Refugees in 2015) given the predictor variables(Number of Refugees in 2010, Rainfall in ml, Population, Famine in the past 15 years, Female and Male population). Based on the score of 0.42 out of 1 we can say the predictor variables are moderately helpful in predicting the number of Refugees. To improve the score it is best to scale the values against the mean, to avoid major outliers and values that might affect the score.
#
# The logistic model is similar to a linear model except it predicts binary values in which 1 represents yes and 0 represents no. My first logistic model looked into whether a country had a recent Civil War based on the number of Refugees in 2010, 2015, Murder Rate, Children out of Primary school, Country's Area, and whether the nation had a recent Famine. The second logistic model was similar to the first except it looked into the target variable of whether the nation had a recent Famine strike. I additionally created another logistic model that predicts the type of Government based on the country's economic and demographic status, I was able to get a score of 0.72.

# %%
Image(filename='../Images/Civil.png')

# %% [markdown]
# A simple explanation of the ROC curves shows how the true values of the Civil War correlate with the predicted values of the Civil War. Looking at the curve, we realize it is above the baseline accuracy, which is a representation of the accuracy of randomly guessing. We can further say the model is doing a good job in estimating the Civil War values compared to if we randomly guessed the values. The Area under the curve is also a good measure of how good the classifier is, we received a score of 0.91 which is a strong score.
#
# Looking at the Famine curve we can see that the curve is always above the baseline which means that the model predicts the target better than randomly guessing. The Area under the curve is 0.95 which tells us that the predictors are helpful in predicting a country's Famine status.

# %%
Image(filename='../Images/Famine.png')

# %%
Image(filename='../Images/Civil_War.png')

# %% [markdown]
# A simple explanation of precision, is the ratio of how often the variable is correct when the model predicts "yes". In easier terms, we would be comparing the predictions with the original values of the variable. Recall is how often the model predicts yes, when the variable is yes. Similarly we would look into the original values and the predictions to see how often both are yes. The best curve would be a linearly positive line; however, this is almost impossible when fitting a model.
#
# Applying the same knowledge from the previous curve, we can look into whether the precision recall curve is helpful in understanding Famine. Based on the area under the precision recall curve, we can say its a moderately strong model and is helpful in predicting the target variable.

# %%
Image(filename='../Images/Recent_Famine.png')

# %%
Image(filename='../Images/pca_image.png')

# %% [markdown]
# A simple way to think about PCA, is a transformation that transforms the coordinate system so the axes represent the data for each variable. In the case of the linear model, I looked into the number of refugees in 2010, Rainfall, Population, whether a country had a recent famine, Female and Male population. By using PCA, we can reduce the number of dimensions and the lose the least amount of variance in our data.

# %%
Image(filename='../Images/decision_entropy.png')

# %% [markdown]
# The tree above shows the best path to find the variables that suit the model to predict whether a country had a civil war or not. Values traversing towards the left means that in the previous condition it was true, while a value traversing towards the right means that the condition was false. The sample's value is the number of observations in that node before splitting.

# %% [markdown]
# # World Maps

# %%
# %%HTML
# <iframe
#   src="https://public.tableau.com/profile/publish/Refugees_2010/Sheet2#!/publish-confirm"
#   width="1000px"
#   height="1000px">
# </iframe>
# Out:
# <iframe
#   src="https://public.tableau.com/profile/publish/Refugees_2010/Sheet2#!/publish-confirm"
#   width="1000px"
#   height="1000px">
# </iframe>

# %% [markdown]
# The tableau visualization above shows a gradient map that visualizes the number of refugees in 2010 and 2015. As the color gets darker the number of refugees in the country is higher and vice versa. By moving a mouse over the country we can see the values associated with the country. Based on the results we can see a huge increase in refugees in Turkey between 2010 and 2015.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based on the country's profile we can say there is an impact on the number of refugees who will find asylum in the country. If there a high number of refugees in 2010, GDP, and number of immigrants there is a higher chance of refugees in 2015. If there is a high number of Rainfall, and Murder Rate there is a chance of a descent between 2010 and 2015.
#
# Considering the European crisis and recent incidents with transportation there is a higher number of refugees finding asylum in Asia, and South American countries. Based on the tableau map visualization there is a possibility that countries in North America and Oceania will start accepting refugees to prevent an overflow in the other continents.
#
# Some ways to improve the refugee issue is to provide a location where refugees feel welcomed by providing the bare necessities, resettle refugees if needed, and provided stricter rules for the people who don't make the refugees feel welcomed.
