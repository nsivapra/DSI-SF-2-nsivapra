# %% [markdown]
# # Introduction

# %% [markdown]
# The definition of a refugee, according to the 1967 Protocol Relating to the Status of Refugees, is an individual who due to fear of being persecuted for reasons of race, religion, nationality, membership of a political group, is outside his/her national country, and is unable to find protection in his/her national country. People who move in groups to avoid war or civil conflict are often considered as refugees. A refugee isn't an individual who stateless or denied entrance into a country. Instead the term "internally displaced people" (IDP) is used to define those individuals who may have moved for the same reasons as refugees but have not crossed the border. Recently Europe had a migration crisis, in which more than a million refugees crossed into Europe, causing a division in the European Union regarding the best way to deal with resettling people. This problem has caused the EU to relocate most of their refugees in Italy and Greece. Between the years 2010 and 2015 there has been a major spike in the number of refugees trying to find asylum. Due to this spike this has led to the European refugee crisis, in which there have been accidents with transportation and overpopulation. According to the UNHCR, the top three nationalities of the refugees, between January 2015 and March 2016 were Syria, Afghan, and Iraq. In 2015 the demographic of refugees and migrants, were 58% men, 17% women, and 25% children. The number of deaths hit an all time high in April 2015, when five boats carrying 2000 migrants to Europe sank in the Mediterranean Sea, in which the death toll was estimated at 1,200 people.
#
# The Syrian Conflict has been an ongoing issue in which 250,000 citizens have lost their lives over a war that started with an armed conflict. Similarly, there have been multiple civil wars and protests that have led citizens to find asylum in different countries. After reading into these conflicts, I decided to look into the recent trends in the acceptance of refugees. Previously, there have been issues with refugees being treated poorly, and lack of a safe community. By looking into a country's profile, including the population, murder rate by 1000, poverty, etc. I hope to be able to see the correlation between these variables and the refugees in 2015. Similarly I hope to see if the country's profile can predict if the country previously had a civil war or a famine strike in the past 15 years.

# %% [markdown]
# # Visualizations

# %%
from IPython.display import Image
Image(filename='../Images/HeatMap.png')

# %% [markdown]
# The heatmap above is a visualization that looks into the relationship between every numeric variable. The scale on the right tells us what each color represents in terms of the slope. A dark red color represents a strong positive relationship, while a dark blue color represents a strong negative relationship. For example, poverty and children out of school, have a moderately positive slope, while GDP and Poverty have a moderately negative relationship.

# %%
Image(filename='../Images/Rain-Ref.png')

# %% [markdown]
# This jointplot looks into correlation and the distribution of values in Rainfall and Refugees in 2015. Based on the slope we can say the variables are correlated negatively. The histograms above show the distribution of the values, which would be helpful in determining the mean. We can estimate the mean for the Rainfall to be around 500 based on the histogram.

# %%
Image(filename='../Images/Imm-Ref.png')

# %% [markdown]
# The jointplot above shows the relationship between Immigrants and Refugees in 2015. Looking at the values and slope we can say Immigrants and Refugees are correlated in a moderate positive manner. Based on the histogram we can say most of the Immigrants and Refugees are between 0 and 10000000.

# %%
Image(filename='../Images/Continent.png')

# %% [markdown]
# The Bar chart above shows the relationship between the continent and the number of Refugees in 2010, and 2015. I included this group by to see if location plays a role in the number of refugees accepted. Based on the results we can say Asia accepts the most refugees in 2010 and 2015. Oceania accepted the least number of refugees in 2010, while North America accepted the least refugees in 2015.

# %%
Image(filename='../Images/Government.png')

# %% [markdown]
# The Bar chart above shows the relationship between the government type and the number of Refugees in 2010 and 2015. According the chart, Absolute Monarcy took the least number in 2010, and 2015, while Republic took the most in 2010 and 2015. A country of the type constitutional monarchy had a slight increase in acceptance, while Republic had a huge increase between those years.

# %%
Image(filename='../Images/Line.png')

# %% [markdown]
# The line graph shows the relationship between the Murder Rate and Children out of school by continent. We can assume Europe to be the safest continent as it contains the least Murder and children out of school, while North America and Africa might be the unsafest continent. Africa has the highest children out of school while North America has the highest Murder Rate.

# %%
Image(filename='../Images/GDP-Imm.png')

# %% [markdown]
# This Bar chart looks into the GDP and number of Immigrants by Continent. According to the chart Africa has the lowest GDP and accepted the least Immigrants. While North America has the highest GDP and accepted the most Immigrants. Based on the chart we could say both variables have a positive correlation.

# %%
Image(filename='../Images/Country.png')

# %% [markdown]
# The Bar chart above looks into all the countries with most than 100000 Refugees in 2010 and 2015. Based on the visual Pakistan accepted less in 2015 compared to 2010, while Ethiopia and Cameroon had an increase in refugees accepted. Both China and Bangladesh accepted roughly the same number in 2010 and 2015.

# %% [markdown]
# # Models

# %% [markdown]
# The linear regression model is helpful in predicting the target variable (Number of Refugees in 2015) given the predictor variables(Number of Refugees in 2010, Density (population/mi$^2$), Population, Famine in the past 15 years, Female and Male population).
#
# The logistic model is similar to a linear model except it predicts non numeric types, in this case I will be predicting the Continent. The model looks into the continent of a country based on the number of Refugees in 2010, 2015, Murder Rate, Children out of school, Area, and Famine strikes. I also set variables that will later be used in the ROC and PR curves to predict Civil War and Famine. I used the number of Refugees in 2010, 2015, Murder Rate, Children out of school, and Area to predict either Civil War or Famine.

# %%
Image(filename='../Images/Civil.png')

# %% [markdown]
# The ROC curve is a metric that looks into the False Positive Rate (when the model predicts civil war and it is not civil war) vs the True Positive Rate (when the model predicts civil war and it is civil war). It is helpful in seeing whether the model performs better than random guessing, which is seen by the baseline accuracy. The AUC can determine whether the classifier is good when it approaches 1, and not so good when it approaches 0. Based on the AUC score of 0.81 we can conclude the predictor variables are helpful in predicting recent civil wars.

# %%
Image(filename='../Images/Famine.png')

# %% [markdown]
# This ROC curve looks into the false positive rate (model predicts Famine when in truth it is not Famine) vs the true positive rate (model predicts Famine and it is Famine). Based on the curve being above the baseline, we can conclude the model is doing better than randomly guessing. The AUC of 0.86 tells us that the predictor variables are helpful in predicting recent Famine.

# %%
Image(filename='../Images/Civil_War.png')

# %% [markdown]
# The precision recall curve looks at the recall (how often the model predicts civil war when it is civil war) vs the precision (when the model predicts civil war how often is it correct). The f1 score is a metric that calculates accuracy based on the recall and precision. Based on the f1 score we can conclude the model predicts civil war with an average accuracy.

# %%
Image(filename='../Images/Recent_Famine.png')

# %% [markdown]
# This PR curve looks into the recall and precision of recent famine. Based on the curve we can see as the recall increases the precision slowly decreases. The PRAUC is helpful in determining the accuracy of the model in predicting the target variable. Looking at the score of 0.47 we can conclude the accuracy of predicting famine is moderate.

# %%
Image(filename='../Images/pca_image.png')

# %% [markdown]
# A simple way to think about PCA, is a transformation that transforms the coordinate system so the axes represent the data for each variable. In the case of the linear model, I looked into the number of refugees in 2010, Rainfall, Population, whether a country had a recent famine, Female and Male population. By using PCA, we can reduce the number of dimensions and the lose the least amount of variance in our data. The plot above shows the relationship between each component against itself, in which the diagonal values are histograms and the rest are pairplots.

# %%
Image(filename='../Images/decision_cont.png')

# %% [markdown]
# The tree above shows the best path to find the variables that suit the model to predict the continent of a country. Values traversing towards the left means that in the previous condition it was true, while a value traversing towards the right means that the condition was false. The sample's value is the number of observations in that node before splitting. Based on the entropy value of 0, we can say Area, Refugees_2010, and Murder Rate was helpful in finding the variables to achieve the highest score and lowest entropy.

# %%
Image(filename='../Images/decision_ref.png')

# %% [markdown]
# According to the decision tree above, the best path to achieving the lowest mse contains the variable Refugees 2010, Population and Density. Another path to a low mse node, looks into the Population, and Refugees_2010.

# %% [markdown]
# # World Maps

# %%
# %%HTML
# <iframe
#   src="https://public.tableau.com/profile/publish/Refugees_2010/Sheet2#!/publish-confirm"
#   width="1000px"
#   height="1000px">
# </iframe>
# Out:
# <iframe
#   src="https://public.tableau.com/profile/publish/Refugees_2010/Sheet2#!/publish-confirm"
#   width="1000px"
#   height="1000px">
# </iframe>

# %% [markdown]
# The tableau visualization above shows a gradient map that visualizes the number of refugees in 2010 and 2015. As the color gets darker the number of refugees in the country is higher and vice versa. By moving a mouse over the country we can see the values associated with the country. Based on the results we can see a huge increase in refugees in Turkey between 2010 and 2015. Syria and Canada had a drop in the number of refugees accepted, primarily due to conflicts and political wars (Syria War).

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based on the country's profile we can say there is an impact on the number of refugees who will find asylum in the country. If there a high number of refugees in 2010, GDP, and number of immigrants there is a higher chance of refugees in 2015. If there is a high number of Rainfall, and Murder Rate there is a chance of a descent between 2010 and 2015.
#
# Considering the European crisis and recent incidents with transportation there is a higher number of refugees finding asylum in Asia, and South American countries. Based on the tableau map visualization there is a possibility that countries in North America and Oceania will start accepting refugees to prevent an overflow in the other continents.
#
# Some ways to improve the refugee issue is to provide a location where refugees feel welcomed by providing the bare necessities, resettle refugees if needed, and provided stricter rules for the people who don't make the refugees feel welcomed.
